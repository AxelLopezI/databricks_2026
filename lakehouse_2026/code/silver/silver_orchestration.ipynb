# %% [markdown]
# # Orchestration logic
# Single entry point for the silver layer in Databricks Jobs. This notebook programmatically runs all silver notebooks in sequence.

# %%
notebooks = [
    "./crm/silver_crm_cust_info",
    "./crm/silver_crm_prd_info",
    "./crm/silver_crm_sales_details",
    "./erp/silver_erp_cust_az12",
    "./erp/silver_erp_loc_a101",
    "./erp/silver_erp_px_cat_g1v2"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
