# %% [markdown]
# # Orchestration logic
# Single entry point for the gold layer in Databricks Jobs. This notebook programmatically runs all gold notebooks in sequence.

# %%
notebooks = [
    "./gold_dim_customers",
    "./gold_dim_products",
    "./gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
